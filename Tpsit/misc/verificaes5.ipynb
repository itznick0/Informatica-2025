# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = plt.imread("7.1.01.tiff")
B = plt.imread("7.1.10.tiff")

# %%
mask = np.full((512, 512), False)
mask[200:340, 130:400] = True

# %%
fusion = B.copy()
fusion[mask] = A[mask]
plt.imshow(fusion, cmap="gray", vmin=0, vmax=255)
